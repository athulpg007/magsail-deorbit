# %%
import numpy as np
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import random
# %matplotlib notebook


fig = pyplot.figure(figsize=(9,9))
ax = Axes3D(fig)

x_arr1 = np.loadtxt('species_1_x_01000.txt')
y_arr1 = np.loadtxt('species_1_y_01000.txt')
z_arr1 = np.loadtxt('species_1_z_01000.txt')

x_arr2 = np.loadtxt('species_2_x_01000.txt')
y_arr2 = np.loadtxt('species_2_y_01000.txt')
z_arr2 = np.loadtxt('species_2_z_01000.txt')

ax.view_init(elev=-90., azim=0)
ax.scatter(x_arr1, y_arr1, z_arr1, s=3.5, alpha=0.05)
ax.scatter(x_arr2, y_arr2, z_arr2, s=5)
pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
len(x_arr1)
# Out:
# 68921

# %%
x_arr1[0:60000:1000]
# Out:
# array([-0.1  , -0.1  , -0.095, -0.095, -0.09 , -0.09 , -0.085, -0.08 ,
#        -0.08 , -0.075, -0.075, -0.07 , -0.065, -0.065, -0.06 , -0.06 ,
#        -0.055, -0.05 , -0.05 , -0.045, -0.045, -0.04 , -0.035, -0.035,
#        -0.03 , -0.03 , -0.025, -0.02 , -0.02 , -0.015, -0.015, -0.01 ,
#        -0.005, -0.005, -0.   , -0.   ,  0.005,  0.01 ,  0.01 ,  0.015,
#         0.015,  0.02 ,  0.02 ,  0.025,  0.03 ,  0.03 ,  0.035,  0.035,
#         0.04 ,  0.045,  0.045,  0.05 ,  0.05 ,  0.055,  0.06 ,  0.06 ,
#         0.065,  0.065,  0.07 ,  0.075])
