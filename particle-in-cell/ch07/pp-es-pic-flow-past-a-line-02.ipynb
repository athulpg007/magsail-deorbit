# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
i = 1

den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=21)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1 +  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()

# %%
i = 40
den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=21)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1+  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()

# %%
i = 80
den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=21)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1 +  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()

# %%
i = 120
den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=21)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1 +  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()

# %%
i = 160
den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=21)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1 +  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()

# %%
i = 200
den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=21)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1 +  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()

# %%
i = 240
den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=21)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1 +  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()

# %%
i = 240
den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=21)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1 +  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()

# %%
i = 280

den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=21)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1 +  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()

# %%
i = 320
den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=21)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1 +  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()

# %%
i = 360
den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=21)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1 +  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()

# %%
i = 400
den1 = np.load('01den_'+str(i).zfill(4)+'.npy')

x = np.linspace(-0.1,0.1,21)
z = np.linspace(0.0, 0.4, 41)

zgrid, xgrid = np.meshgrid(z,x)

plt.figure(figsize=(9.5*1.4,4*1.4))
plt.rc('font',family='Times New Roman')
plt.contourf(zgrid,xgrid,den1[:,10,:]/1E10, levels=51)
cbar=plt.colorbar()
cbar.ax.tick_params(labelsize=18)
cbar.set_label(r'$N \times 10^{10}$', labelpad=-27, y=1.10, rotation=0, fontsize=18)

theta = np.linspace(0, 2*np.pi, 101)

z1 = 0.1 +  0.02*np.cos(theta)
x1 = 0.0 +  0.02*np.sin(theta)

plt.plot(z1,x1,'w', linestyle='solid', linewidth=2.0)

ax = plt.gca()
ax.tick_params(direction='in')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
plt.tick_params(direction='in')
plt.tick_params(axis='x',labelsize=18)
plt.tick_params(axis='y',labelsize=18)

plt.xlabel('Z, m',fontsize=18)
plt.ylabel("X, m",fontsize=18)


plt.show()
