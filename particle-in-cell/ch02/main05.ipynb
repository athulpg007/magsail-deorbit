# %%
from world05 import World
from species05 import Species
import numpy as np

# %%
def run():

    world=World(21,21,21)
    world.setTime(2E-10,100)
    world.setExtents(-0.1, -0.1, 0.0 , 0.1, 0.1, 0.2)

    species1 = Species("O+", 16*world.AMU, world.QE, world)
    species2 = Species("e-", world.ME, -1.0*world.QE, world)

    world.addSpeciesList([species1,species2])

    species1.loadParticlesBoxQS(world.x0, world.xm, 1E11, [41, 41, 41])
    species2.loadParticlesBoxQS(world.x0, world.xc, 1E11, [21, 21, 21])

    species1.computeNumberDensity()
    species2.computeNumberDensity()

    world.computeChargeDensity()

    world.potentialSolver5(1.8,10000, 1E-4)

    world.efSolver2()

    for i in range(1,10):
        species1.advance()
        species2.advance()

        species1.computeNumberDensity()
        species2.computeNumberDensity()

        world.computeChargeDensity()

        world.potentialSolver5(1.8,10000, 1E-4)

        world.efSolver2()

        print("ts = "+str(i)+", nO+: "+str(len(species1.particleList))+", ne-: "+str(len(species2.particleList)))

# %%
run()
# Out:
# /home/athul/Dropbox/Codes/magsail/particle-in-cell/world05.py:600: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "potentialSolver5" failed type inference due to: Untyped global name 'str': cannot determine Numba type of <class 'type'>
#
# File "world05.py", line 707:
#     def potentialSolver5(self, w, max_it, tol):
#         <source elided>
#         if (converged==False):
#             print("Gauss-Seidel failed to converge, L2 = "+str(L2))
#             ^
#
#   @jit
# /home/athul/Dropbox/Codes/magsail/particle-in-cell/world05.py:600: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "potentialSolver5" failed type inference due to: cannot determine Numba type of <class 'numba.dispatcher.LiftedLoop'>
#
# File "world05.py", line 636:
#     def potentialSolver5(self, w, max_it, tol):
#         <source elided>
#         # solve potential
# ...
